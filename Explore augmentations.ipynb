# %% [markdown]
# # Explore data augmentations
#
# This notebook will be used to test different data augmentation strategies. In your config file, you can modify the augmentations by adding `data_augmentation_options`. For example, I would like to add a random RGB to gray transform with a probability of 0.2:
# ```
# data_augmentation_options {
#     random_rgb_to_gray {
#     probability: 0.2
#     }
# ```
#
# A complete list of augmentation is provided the [`preprocessor.proto` file of the Tf Object Detection API](https://github.com/tensorflow/models/blob/master/research/object_detection/protos/preprocessor.proto).

# %% [markdown]
# ### Helper functions

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Rectangle

# %%
def recenter_image(image):
    # ssd preprocessing
    image += [123.68, 116.779, 103.939]
    return image

def display_instances(image, bboxes, classes):
    image = recenter_image(image)
    w, h, _ = image.shape
    # resize the bboxes
    bboxes[:, [0, 2]] *= w
    bboxes[:, [1, 3]] *= h
    
    f, ax = plt.subplots(1, figsize=(10, 10))
    ax.imshow(image.astype(np.uint8))
    for bb, cl in zip(bboxes, classes):
        y1, x1, y2, x2 = bb
        rec = Rectangle((x1, y1), x2-x1, y2-y1, facecolor='none', edgecolor='r', linewidth=2)
        ax.add_patch(rec)
    plt.show()

def display_batch(batch):
    # get images, bboxes and classes
    batched_images = batch[0]['image'].numpy()
    batched_bboxes = batch[1]['groundtruth_boxes'].numpy()
    batched_classes = batch[1]['groundtruth_classes'].numpy()
    num_bboxes = batch[1]['num_groundtruth_boxes'].numpy()
    batch_size = batched_images.shape[0]
    for idx in range(batch_size):
        display_instances(batched_images[idx, ...], 
                          batched_bboxes[idx, :num_bboxes[idx], :],
                          batched_classes[idx, ...])

# %% [markdown]
# ### Display augmentations

# %%
from utils import get_train_input

# %%
train_dataset = get_train_input("experiments/ssd-augmented/pipeline_new.config")
print('done')
# Out:
# INFO:tensorflow:Reading unweighted datasets: ['/workspaces/urbar-road-osbtacle-detection/data/train/segment-13840133134545942567_1060_000_1080_000_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-14503113925613619599_975_506_995_506_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-1357883579772440606_2365_000_2385_000_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-13679757109245957439_4167_170_4187_170_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-18441113814326864765_725_000_745_000_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-1907783283319966632_3221_000_3241_000_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-14004546003548947884_2331_861_2351_861_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-14763701469114129880_2260_000_2280_000_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-1918764220984209654_5680_000_5700_000_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-13390791323468600062_6718_570_6738_570_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-2036908808378190283_4340_000_4360_000_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-2259324582958830057_3767_030_3787_030_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-2206505463279484253_476_189_496_189_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-14106113060128637865_1200_000_1220_000_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-1887497421568128425_94_000_114_000_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-14742731916935095621_1325_000_1345_000_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-1172406780360799916_1660_000_1680_000_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-1005081002024129653_5313_150_5333_150_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-2114574223307001959_1163_280_1183_280_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-14133920963894906769_1480_000_1500_000_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-18286677872269962604_3520_000_3540_000_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-18244334282518155052_2360_000_2380_000_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-13944915979337652825_4260_668_4280_668_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-14276116893664145886_1785_080_1805_080_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-1432918953215186312_5101_320_5121_320_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-18233614482685846350_7060_000_7080_000_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-200287570390499785_2102_000_2122_000_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-1940032764689855266_3690_210_3710_210_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-1972128316147758939_2500_000_2520_000_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-18403940760739364047_920_000_940_000_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/tr ...
# INFO:tensorflow:Reading record datasets for input file: ['/workspaces/urbar-road-osbtacle-detection/data/train/segment-13840133134545942567_1060_000_1080_000_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-14503113925613619599_975_506_995_506_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-1357883579772440606_2365_000_2385_000_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-13679757109245957439_4167_170_4187_170_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-18441113814326864765_725_000_745_000_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-1907783283319966632_3221_000_3241_000_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-14004546003548947884_2331_861_2351_861_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-14763701469114129880_2260_000_2280_000_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-1918764220984209654_5680_000_5700_000_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-13390791323468600062_6718_570_6738_570_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-2036908808378190283_4340_000_4360_000_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-2259324582958830057_3767_030_3787_030_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-2206505463279484253_476_189_496_189_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-14106113060128637865_1200_000_1220_000_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-1887497421568128425_94_000_114_000_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-14742731916935095621_1325_000_1345_000_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-1172406780360799916_1660_000_1680_000_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-1005081002024129653_5313_150_5333_150_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-2114574223307001959_1163_280_1183_280_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-14133920963894906769_1480_000_1500_000_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-18286677872269962604_3520_000_3540_000_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-18244334282518155052_2360_000_2380_000_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-13944915979337652825_4260_668_4280_668_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-14276116893664145886_1785_080_1805_080_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-1432918953215186312_5101_320_5121_320_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-18233614482685846350_7060_000_7080_000_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-200287570390499785_2102_000_2122_000_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-1940032764689855266_3690_210_3710_210_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-1972128316147758939_2500_000_2520_000_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detection/data/train/segment-18403940760739364047_920_000_940_000_with_camera_labels.tfrecord', '/workspaces/urbar-road-osbtacle-detect ...
# INFO:tensorflow:Number of filenames to read: 135
# done

# %%
# %matplotlib inline

for batch in train_dataset.take(2):
    display_batch(batch)
